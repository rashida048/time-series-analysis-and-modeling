# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FB_data.csv')
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0  6/20/2019  190.949997  191.160004  187.639999  189.529999  189.529999
# 1  6/21/2019  188.750000  192.000000  188.750000  191.139999  191.139999
# 2  6/24/2019  192.419998  193.979996  191.570007  192.600006  192.600006
# 3  6/25/2019  192.880005  193.139999  188.130005  188.839996  188.839996
# 4  6/26/2019  189.539993  190.759995  187.309998  187.660004  187.660004
#
#      Volume
# 0  14635700
# 1  22751200
# 2  15509000
# 3  16750300
# 4  12808600

# %%
df_comp = df.copy()

# %%
df_comp.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  253.000000  253.000000  253.000000  253.000000  253.000000
# mean   195.771304  198.223637  193.238143  195.928419  195.928419
# std     18.912673   18.630595   19.295351   19.033137   19.033137
# min    139.750000  148.179993  137.100006  146.009995  146.009995
# 25%    184.619995  186.729996  182.559998  185.130005  185.130005
# 50%    194.699997  197.070007  192.740005  194.470001  194.470001
# 75%    207.020004  210.380005  205.309998  207.789993  207.789993
# max    240.960007  241.210007  235.550003  238.789993  238.789993
#
#              Volume
# count  2.530000e+02
# mean   1.795714e+07
# std    8.708030e+06
# min    6.046300e+06
# 25%    1.176170e+07
# 50%    1.534030e+07
# 75%    2.166420e+07
# max    5.016290e+07

# %%
import matplotlib.pyplot as plt

# %%
df_comp.Open.plot()
plt.show()

# %%
import scipy.stats
import pylab

# %%
scipy.stats.probplot(df_comp.Open, plot=pylab)
pylab.show()

# %%
df_comp.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  253.000000  253.000000  253.000000  253.000000  253.000000
# mean   195.771304  198.223637  193.238143  195.928419  195.928419
# std     18.912673   18.630595   19.295351   19.033137   19.033137
# min    139.750000  148.179993  137.100006  146.009995  146.009995
# 25%    184.619995  186.729996  182.559998  185.130005  185.130005
# 50%    194.699997  197.070007  192.740005  194.470001  194.470001
# 75%    207.020004  210.380005  205.309998  207.789993  207.789993
# max    240.960007  241.210007  235.550003  238.789993  238.789993
#
#              Volume
# count  2.530000e+02
# mean   1.795714e+07
# std    8.708030e+06
# min    6.046300e+06
# 25%    1.176170e+07
# 50%    1.534030e+07
# 75%    2.166420e+07
# max    5.016290e+07

# %%
df_comp.Date= pd.to_datetime(df_comp.Date, dayfirst = True)
df_comp.head()
# Out:
# <ipython-input-10-b80ff4bff791>:1: UserWarning: Parsing dates in MM/DD/YYYY format when dayfirst=True was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_comp.Date= pd.to_datetime(df_comp.Date, dayfirst = True)
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2019-06-20  190.949997  191.160004  187.639999  189.529999  189.529999
# 1 2019-06-21  188.750000  192.000000  188.750000  191.139999  191.139999
# 2 2019-06-24  192.419998  193.979996  191.570007  192.600006  192.600006
# 3 2019-06-25  192.880005  193.139999  188.130005  188.839996  188.839996
# 4 2019-06-26  189.539993  190.759995  187.309998  187.660004  187.660004
#
#      Volume
# 0  14635700
# 1  22751200
# 2  15509000
# 3  16750300
# 4  12808600

# %%
df_comp.Date.describe()
# Out:
# <ipython-input-11-52ff0a35547c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_comp.Date.describe()
# count                     253
# unique                    253
# top       2019-06-20 00:00:00
# freq                        1
# first     2019-01-07 00:00:00
# last      2020-12-06 00:00:00
# Name: Date, dtype: object

# %%
df_comp.set_index("Date", inplace = True)

# %%
df_comp.asfreq('d')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-07  195.210007  195.279999  191.929993  193.000000  193.000000
# 2019-01-08  194.169998  198.470001  190.880005  192.729996  192.729996
# 2019-01-09         NaN         NaN         NaN         NaN         NaN
# 2019-01-10  179.149994  179.839996  174.880005  175.809998  175.809998
# 2019-01-11  192.850006  194.110001  189.910004  193.619995  193.619995
# ...                ...         ...         ...         ...         ...
# 2020-12-02  207.850006  211.220001  207.399994  210.759995  210.759995
# 2020-12-03  159.539993  166.600006  154.339996  154.470001  154.470001
# 2020-12-04         NaN         NaN         NaN         NaN         NaN
# 2020-12-05  213.289993  215.279999  210.000000  210.100006  210.100006
# 2020-12-06  229.899994  231.660004  224.500000  228.580002  228.580002
#
#                 Volume
# Date
# 2019-01-07  14204700.0
# 2019-01-08  17777000.0
# 2019-01-09         NaN
# ...

# %%
df_comp = df_comp.asfreq('b')
df_comp
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-07  195.210007  195.279999  191.929993  193.000000  193.000000
# 2019-01-08  194.169998  198.470001  190.880005  192.729996  192.729996
# 2019-01-09         NaN         NaN         NaN         NaN         NaN
# 2019-01-10  179.149994  179.839996  174.880005  175.809998  175.809998
# 2019-01-11  192.850006  194.110001  189.910004  193.619995  193.619995
# ...                ...         ...         ...         ...         ...
# 2020-11-30         NaN         NaN         NaN         NaN         NaN
# 2020-12-01         NaN         NaN         NaN         NaN         NaN
# 2020-12-02  207.850006  211.220001  207.399994  210.759995  210.759995
# 2020-12-03  159.539993  166.600006  154.339996  154.470001  154.470001
# 2020-12-04         NaN         NaN         NaN         NaN         NaN
#
#                 Volume
# Date
# 2019-01-07  14204700.0
# 2019-01-08  17777000.0
# 2019-01-09         NaN
# ...

# %%
df_comp.isna().sum()
# Out:
# Open         277
# High         277
# Low          277
# Close        277
# Adj Close    277
# Volume       277
# dtype: int64

# %%
df_comp.Close=df_comp.Close.fillna(method='ffill')

# %%
df_comp.Open=df_comp.Open.fillna(method='bfill')

# %%
df_comp.Volume=df_comp.Volume.fillna(value = df_comp.Volume.mean())

# %%
wn = np.random.normal(loc = df.Open.mean(), scale = df.Open.std(), size=len(df_comp))

# %%
df_comp['wn'] = wn

# %%
df_comp.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  499.000000  223.000000  223.000000  500.000000  223.000000
# mean   197.469799  198.367713  193.336368  201.389499  196.038968
# std     17.416841   18.855951   19.630039   19.940588   19.271578
# min    139.750000  148.179993  137.100006  146.009995  146.009995
# 25%    186.720001  186.925003  182.565002  189.887494  185.360001
# 50%    195.190002  197.240005  192.740005  198.820007  194.720001
# 75%    210.190002  210.490005  205.254998  213.079998  207.489998
# max    240.960007  241.210007  235.550003  238.789993  238.789993
#
#              Volume          wn
# count  5.000000e+02  500.000000
# mean   1.823602e+07  196.961005
# std    5.986041e+06   18.982660
# min    6.046300e+06  120.217767
# 25%    1.648068e+07  184.615119
# 50%    1.823602e+07  197.027040
# 75%    1.823602e+07  209.990156
# max    5.016290e+07  255.754986

# %%
df_comp.wn.plot()
plt.title("White Noise Time-Series", size = 24)
plt.show()

# %%
import statsmodels.tsa.stattools as sts

# %%
sts.adfuller(df_comp.Volume)
# Out:
# (-7.818055206761233,
#  6.78603816659495e-12,
#  2,
#  497,
#  {'1%': -3.4435761493506294,
#   '5%': -2.867372960189225,
#   '10%': -2.5698767442886696},
#  16201.388947963707)

# %% [markdown]
# -7.81 is the test statistics there is 1, 5 and 10% critical value as a dictionary towards the end as well.
#
# -7.818 is smaller than all the critical values. Thus there is enough evidence of stationarity in the data.
#
# The next is p-value of 6.78 that means there is roughly 678% chance of not rejecting the null. We can confirm the stationarity.
#
# 2 is the number of lags in the regression when determining the t-stat. Some autocorrelation going back 2 periods. We will take into account when picking the appropriate model.
#
# 497 used the number of observations used in the analysis
#
# The size of the dataset should be 497 + 2
#
# 16201.39 is the autocorrelation. The lower the values the easier it is to predict for future.

# %%
sts.adfuller(df_comp.wn)
# Out:
# (-20.788943238665905,
#  0.0,
#  0,
#  499,
#  {'1%': -3.4435228622952065,
#   '5%': -2.867349510566146,
#   '10%': -2.569864247011056},
#  4202.35354751124)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels
s_dec_additive = statsmodels.tsa.seasonal.seasonal_decompose(df_comp.Volume, model='additive')

# %%
s_dec_additive.plot()

# %%
s_dec_multiplicative = statsmodels.tsa.seasonal.seasonal_decompose(df_comp.Volume, model='multiplicative')
s_dec_multiplicative.plot()

# %%
import statsmodels.graphics.tsaplots as sgt

# %%
sgt.plot_acf(df.Volume, lags = 40, zero = False)
plt.title("ACF S&P", size = 24)
plt.show()

# %% [markdown]
# correlation can only take values between -1 and 1. the first line represents the coefficient value for 1 period ago. The second one represents the coeff of 2 periods ago and so on. the blue area around the X-axis represent sthe significance. the blue dots outside the blue zone suggests there is aucorrelation. The blue dots inside the blue zone says that there is no autocorrelation. The greater the distance from time, the more unlikely it is that the autocorrelation persists. That's why the blue zone get wider and wider over time.

# %%
sgt.plot_acf(df_comp.wn, lags = 40, zero = False)
plt.title("ACF S&P", size = 24)
plt.show()

# %%
sgt.plot_pacf(df.Volume, lags = 40, zero=False, method = ('ols'))
plt.title("PACF S&P", size = 24)
plt.show()

# %%
sgt.plot_pacf(df_comp.wn, lags = 40, zero=False, method = ('ols'))
plt.title("PACF wn", size = 24)
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model_ar = ARIMA(df.Volume, order = (1,0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-00002cc7c95e> in <cell line: 1>()
# ----> 1 model_ar = ARIMA(df.Volume, order = (1,0))
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/arima/model.py in __init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     156         # this criteria. Instead, we'll just make sure that the parameter
#     157         # estimates from those methods satisfy the criteria.)
# --> 158         self._spec_arima = SARIMAXSpecification(
#     159             endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     160             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#
# ...

# %%
from datetime import datetime
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/electricity_consumption.csv',
                 parse_dates = ['Bill_Date'])

# %%
df.head()
# Out:
#    Bill_Date  On_peak  Off_peak  Usage_charge  Billed_amount  Billing_days
# 0 2016-01-01      365    1423.5         219.0         247.73            31
# 1 2016-02-01      292    1138.8         175.2         234.11            31
# 2 2016-03-01      130     507.0          78.0         123.85            29
# 3 2016-04-01      117     456.3          70.2         111.22            29
# 4 2016-05-01      136     530.4          81.6         118.37            29

# %%
print("Rows: ", df.shape[0])
print("Columns: ", df.shape[1])
print("unique values: ", df.nunique())
# Out:
# Rows:  53
# Columns:  6
# unique values:  Bill_Date        53
# On_peak          51
# Off_peak         53
# Usage_charge     53
# Billed_amount    52
# Billing_days      9
# dtype: int64

# %%
bill_df = df.set_index("Bill_Date")

# %%
bill_2018 = bill_df['2016':'2028'][['Billed_amount']]

# %%
bill_2018
# Out:
#             Billed_amount
# Bill_Date
# 2016-01-01         247.73
# 2016-02-01         234.11
# 2016-03-01         123.85
# 2016-04-01         111.22
# 2016-05-01         118.37
# 2016-06-01          77.81
# 2016-07-01          86.67
# 2016-08-01         122.40
# 2016-09-01         223.62
# 2016-10-01         152.54
# 2016-11-01         150.54
# 2016-12-01         244.37
# 2017-01-01         263.64
# 2017-02-01         214.32
# 2017-03-01         151.54
# 2017-04-01         118.79
# 2017-05-01         153.18
# 2017-06-01         212.08
# 2017-07-01         281.19
# 2017-08-01         237.97
# 2017-09-01         284.30
# 2017-10-01         172.69
# 2017-11-01         111.51
# 2017-12-01         151.42
# 2018-01-01         267.32
# 2018-02-01         201.35
# 2018-03-01         202.91
# 2018-04-01         150.86
# 2018-05-01         163.07
# 2018-06-01         219.76
# 2018-07-01         283.98
# 2018-08-01         290.15
# 2018-09-01         257.96
# 2018-10-01         327.19
# ...

# %%
#Simple moving average
bill_2018['Billed_amount'].rolling(window=3).mean()
# Out:
# Bill_Date
# 2016-01-01           NaN
# 2016-02-01           NaN
# 2016-03-01    201.896667
# 2016-04-01    156.393333
# 2016-05-01    117.813333
# 2016-06-01    102.466667
# 2016-07-01     94.283333
# 2016-08-01     95.626667
# 2016-09-01    144.230000
# 2016-10-01    166.186667
# 2016-11-01    175.566667
# 2016-12-01    182.483333
# 2017-01-01    219.516667
# 2017-02-01    240.776667
# 2017-03-01    209.833333
# 2017-04-01    161.550000
# 2017-05-01    141.170000
# 2017-06-01    161.350000
# 2017-07-01    215.483333
# 2017-08-01    243.746667
# 2017-09-01    267.820000
# 2017-10-01    231.653333
# 2017-11-01    189.500000
# 2017-12-01    145.206667
# 2018-01-01    176.750000
# 2018-02-01    206.696667
# 2018-03-01    223.860000
# 2018-04-01    185.040000
# 2018-05-01    172.280000
# 2018-06-01    177.896667
# 2018-07-01    222.270000
# 2018-08-01    264.630000
# 2018-09-01    277.363333
# 2018-10-01    291.766667
# 2018-11-01    259.546667
# 2018-12-01    224.340000
# ...

# %%
bill_2018['ma_rolling_3'] = bill_2018['Billed_amount'].rolling(window=3).mean().shift(1)

# %%
bill_2018.plot()
# Out:
# <Axes: xlabel='Bill_Date'>

# %% [markdown]
# weighted moving avergae = (t*weighting factor) + ((t-1) * weighting - 1) + ((t-n)*weighting factor - n)/n

# %%
def wma(weights):
  def calc(x):
    return (weights*x).mean()
  return calc

# %%
import numpy as np
bill_2018['Billed_amount'].rolling(window=3).apply(wma(np.array([0.5, 1, 1.5])))
# Out:
# Bill_Date
# 2016-01-01           NaN
# 2016-02-01           NaN
# 2016-03-01    181.250000
# 2016-04-01    135.911667
# 2016-05-01    116.900000
# 2016-06-01     96.898333
# 2016-07-01     89.000000
# 2016-08-01    103.058333
# 2016-09-01    167.055000
# 2016-10-01    171.210000
# 2016-11-01    163.386667
# 2016-12-01    197.788333
# 2017-01-01    238.366667
# 2017-02-01    235.768333
# 2017-03-01    191.150000
# 2017-04-01    145.628333
# 2017-05-01    141.443333
# 2017-06-01    176.898333
# 2017-07-01    236.818333
# 2017-08-01    248.061667
# 2017-09-01    268.338333
# 2017-10-01    220.773333
# 2017-11-01    160.701667
# 2017-12-01    141.661667
# 2018-01-01    202.718333
# 2018-02-01    215.018333
# 2018-03-01    213.125000
# 2018-04-01    176.625000
# 2018-05-01    165.640000
# 2018-06-01    189.380000
# 2018-07-01    242.421667
# 2018-08-01    276.361667
# 2018-09-01    273.026667
# 2018-10-01    297.940000
# 2018-11-01    248.801667
# 2018-12-01    195.198333
# ...

# %%
bill_2018['wma_rolling_3']=bill_2018['Billed_amount'].rolling(window=3).apply(wma(np.array([0.5, 1, 1.5]))).shift(1)
bill_2018
# Out:
#             Billed_amount  ma_rolling_3  wma_rolling_3
# Bill_Date
# 2016-01-01         247.73           NaN            NaN
# 2016-02-01         234.11           NaN            NaN
# 2016-03-01         123.85           NaN            NaN
# 2016-04-01         111.22    201.896667     181.250000
# 2016-05-01         118.37    156.393333     135.911667
# 2016-06-01          77.81    117.813333     116.900000
# 2016-07-01          86.67    102.466667      96.898333
# 2016-08-01         122.40     94.283333      89.000000
# 2016-09-01         223.62     95.626667     103.058333
# 2016-10-01         152.54    144.230000     167.055000
# 2016-11-01         150.54    166.186667     171.210000
# 2016-12-01         244.37    175.566667     163.386667
# 2017-01-01         263.64    182.483333     197.788333
# 2017-02-01         214.32    219.516667     238.366667
# 2017-03-01         151.54    240.776667     235.768333
# 2017-04-01         118.79    209.833333     191.150000
# ...

# %%
#exponential moving average
bill_2018['Billed_amount'].ewm(span=3, adjust=False, min_periods=0).mean()
# Out:
# Bill_Date
# 2016-01-01    247.730000
# 2016-02-01    240.920000
# 2016-03-01    182.385000
# 2016-04-01    146.802500
# 2016-05-01    132.586250
# 2016-06-01    105.198125
# 2016-07-01     95.934063
# 2016-08-01    109.167031
# 2016-09-01    166.393516
# 2016-10-01    159.466758
# 2016-11-01    155.003379
# 2016-12-01    199.686689
# 2017-01-01    231.663345
# 2017-02-01    222.991672
# 2017-03-01    187.265836
# 2017-04-01    153.027918
# 2017-05-01    153.103959
# 2017-06-01    182.591980
# 2017-07-01    231.890990
# 2017-08-01    234.930495
# 2017-09-01    259.615247
# 2017-10-01    216.152624
# 2017-11-01    163.831312
# 2017-12-01    157.625656
# 2018-01-01    212.472828
# 2018-02-01    206.911414
# 2018-03-01    204.910707
# 2018-04-01    177.885353
# 2018-05-01    170.477677
# 2018-06-01    195.118838
# 2018-07-01    239.549419
# 2018-08-01    264.849710
# 2018-09-01    261.404855
# 2018-10-01    294.297427
# 2018-11-01    243.893714
# 2018-12-01    198.116857
# ...

# %%
bill_2018['ewm_window_3']=bill_2018['Billed_amount'].ewm(span=3, adjust=False, min_periods=0).mean().shift(1)
bill_2018
# Out:
#             Billed_amount  ma_rolling_3  wma_rolling_3  ewm_window_3
# Bill_Date
# 2016-01-01         247.73           NaN            NaN           NaN
# 2016-02-01         234.11           NaN            NaN    247.730000
# 2016-03-01         123.85           NaN            NaN    240.920000
# 2016-04-01         111.22    201.896667     181.250000    182.385000
# 2016-05-01         118.37    156.393333     135.911667    146.802500
# 2016-06-01          77.81    117.813333     116.900000    132.586250
# 2016-07-01          86.67    102.466667      96.898333    105.198125
# 2016-08-01         122.40     94.283333      89.000000     95.934063
# 2016-09-01         223.62     95.626667     103.058333    109.167031
# 2016-10-01         152.54    144.230000     167.055000    166.393516
# 2016-11-01         150.54    166.186667     171.210000    159.466758
# 2016-12-01         244.37    175.566667     163.386667    155.003379
# ...

# %%
bill_2018['esm_window_3_7']=bill_2018['Billed_amount'].ewm(alpha=0.7, adjust=False, min_periods=3).mean().shift(1)
bill_2018
# Out:
#             Billed_amount  ma_rolling_3  wma_rolling_3  ewm_window_3  \
# Bill_Date
# 2016-01-01         247.73           NaN            NaN           NaN
# 2016-02-01         234.11           NaN            NaN    247.730000
# 2016-03-01         123.85           NaN            NaN    240.920000
# 2016-04-01         111.22    201.896667     181.250000    182.385000
# 2016-05-01         118.37    156.393333     135.911667    146.802500
# 2016-06-01          77.81    117.813333     116.900000    132.586250
# 2016-07-01          86.67    102.466667      96.898333    105.198125
# 2016-08-01         122.40     94.283333      89.000000     95.934063
# 2016-09-01         223.62     95.626667     103.058333    109.167031
# 2016-10-01         152.54    144.230000     167.055000    166.393516
# 2016-11-01         150.54    166.186667     171.210000    159.466758
# 2016-12-01         244.37    175.566667     163.386667    155.003379
# ...

# %%
bill_2018['esm_window_3_3']=bill_2018['Billed_amount'].ewm(alpha=0.3, adjust=False, min_periods=3).mean().shift(1)
bill_2018
# Out:
#             Billed_amount  ma_rolling_3  wma_rolling_3  ewm_window_3  \
# Bill_Date
# 2016-01-01         247.73           NaN            NaN           NaN
# 2016-02-01         234.11           NaN            NaN    247.730000
# 2016-03-01         123.85           NaN            NaN    240.920000
# 2016-04-01         111.22    201.896667     181.250000    182.385000
# 2016-05-01         118.37    156.393333     135.911667    146.802500
# 2016-06-01          77.81    117.813333     116.900000    132.586250
# 2016-07-01          86.67    102.466667      96.898333    105.198125
# 2016-08-01         122.40     94.283333      89.000000     95.934063
# 2016-09-01         223.62     95.626667     103.058333    109.167031
# 2016-10-01         152.54    144.230000     167.055000    166.393516
# 2016-11-01         150.54    166.186667     171.210000    159.466758
# 2016-12-01         244.37    175.566667     163.386667    155.003379
# ...

# %%
((bill_2018['Billed_amount']-bill_2018['ma_rolling_3'])**2).mean()**0.5
# Out:
# 78.72717946455623

# %%
((bill_2018['Billed_amount']-bill_2018['wma_rolling_3'])**2).mean()**0.5
# Out:
# 72.4925892561133

# %%
((bill_2018['Billed_amount']-bill_2018['ewm_window_3'])**2).mean()**0.5
# Out:
# 69.12882156094688

# %%
((bill_2018['Billed_amount']-bill_2018['esm_window_3_7'])**2).mean()**0.5
# Out:
# 66.83253524231746

# %%
((bill_2018['Billed_amount']-bill_2018['esm_window_3_3'])**2).mean()**0.5
# Out:
# 70.5301174049304

# %% [markdown]
# If a time series is stationary around a mean or in linear term

# %%
from statsmodels.tsa.stattools import kpss

# %% [markdown]
# Null hypothesis - data is stationary
#
# Alternative hypothesis - data is not stationary

# %%
tstest = kpss(bill_2018['Billed_amount'], 'ct')
# Out:
# <ipython-input-33-04cf7c0b81bb>:1: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   tstest = kpss(bill_2018['Billed_amount'], 'ct')

# %%
tstest
# Out:
# (0.07628752249745986,
#  0.1,
#  2,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import statsmodels.api as sm
res = sm.tsa.seasonal_decompose(bill_2018['Billed_amount'], model='multiplicative')
resplot = res.plot()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22, 7))
res.trend.plot()
# Out:
# <Axes: xlabel='Bill_Date'>

# %%
res.observed
# Out:
# Bill_Date
# 2016-01-01    247.73
# 2016-02-01    234.11
# 2016-03-01    123.85
# 2016-04-01    111.22
# 2016-05-01    118.37
# 2016-06-01     77.81
# 2016-07-01     86.67
# 2016-08-01    122.40
# 2016-09-01    223.62
# 2016-10-01    152.54
# 2016-11-01    150.54
# 2016-12-01    244.37
# 2017-01-01    263.64
# 2017-02-01    214.32
# 2017-03-01    151.54
# 2017-04-01    118.79
# 2017-05-01    153.18
# 2017-06-01    212.08
# 2017-07-01    281.19
# 2017-08-01    237.97
# 2017-09-01    284.30
# 2017-10-01    172.69
# 2017-11-01    111.51
# 2017-12-01    151.42
# 2018-01-01    267.32
# 2018-02-01    201.35
# 2018-03-01    202.91
# 2018-04-01    150.86
# 2018-05-01    163.07
# 2018-06-01    219.76
# 2018-07-01    283.98
# 2018-08-01    290.15
# 2018-09-01    257.96
# 2018-10-01    327.19
# 2018-11-01    193.49
# 2018-12-01    152.34
# 2019-01-01    196.62
# 2019-02-01    190.07
# 2019-03-01    198.57
# 2019-04-01    115.15
# 2019-05-01    153.18
# 2019-06-01    138.53
# ...

# %%
print(res.trend)
# Out:
# Bill_Date
# 2016-01-01           NaN
# 2016-02-01           NaN
# 2016-03-01           NaN
# 2016-04-01           NaN
# 2016-05-01           NaN
# 2016-06-01           NaN
# 2016-07-01    158.432083
# 2016-08-01    158.270417
# 2016-09-01    158.599583
# 2016-10-01    160.068750
# 2016-11-01    161.834583
# 2016-12-01    168.879583
# 2017-01-01    182.579167
# 2017-02-01    195.499583
# 2017-03-01    202.843333
# 2017-04-01    206.211250
# 2017-05-01    205.424583
# 2017-06-01    199.925417
# 2017-07-01    196.205833
# 2017-08-01    195.818750
# 2017-09-01    197.418750
# 2017-10-01    200.895417
# 2017-11-01    202.643750
# 2017-12-01    203.375833
# 2018-01-01    203.812083
# 2018-02-01    206.102500
# 2018-03-01    207.179167
# 2018-04-01    212.519167
# 2018-05-01    222.372500
# 2018-06-01    225.826667
# 2018-07-01    222.919167
# 2018-08-01    219.503333
# 2018-09-01    218.852500
# 2018-10-01    217.183750
# 2018-11-01    215.283750
# 2018-12-01    211.487083
# ...

# %%
print(res.seasonal)
# Out:
# Bill_Date
# 2016-01-01    1.236123
# 2016-02-01    0.999747
# 2016-03-01    0.887512
# 2016-04-01    0.607358
# 2016-05-01    0.736968
# 2016-06-01    0.901290
# 2016-07-01    1.099431
# 2016-08-01    1.192012
# 2016-09-01    1.481501
# 2016-10-01    1.119069
# 2016-11-01    0.768554
# 2016-12-01    0.970435
# 2017-01-01    1.236123
# 2017-02-01    0.999747
# 2017-03-01    0.887512
# 2017-04-01    0.607358
# 2017-05-01    0.736968
# 2017-06-01    0.901290
# 2017-07-01    1.099431
# 2017-08-01    1.192012
# 2017-09-01    1.481501
# 2017-10-01    1.119069
# 2017-11-01    0.768554
# 2017-12-01    0.970435
# 2018-01-01    1.236123
# 2018-02-01    0.999747
# 2018-03-01    0.887512
# 2018-04-01    0.607358
# 2018-05-01    0.736968
# 2018-06-01    0.901290
# 2018-07-01    1.099431
# 2018-08-01    1.192012
# 2018-09-01    1.481501
# 2018-10-01    1.119069
# 2018-11-01    0.768554
# 2018-12-01    0.970435
# 2019-01-01    1.236123
# 2019-02-01    0.999747
# 2019-03-01    0.887512
# ...

# %%
res.resid
# Out:
# Bill_Date
# 2016-01-01         NaN
# 2016-02-01         NaN
# 2016-03-01         NaN
# 2016-04-01         NaN
# 2016-05-01         NaN
# 2016-06-01         NaN
# 2016-07-01    0.497574
# 2016-08-01    0.648785
# 2016-09-01    0.951714
# 2016-10-01    0.851570
# 2016-11-01    1.210337
# 2016-12-01    1.491092
# 2017-01-01    1.168150
# 2017-02-01    1.096545
# 2017-03-01    0.841768
# 2017-04-01    0.948469
# 2017-05-01    1.011814
# 2017-06-01    1.176975
# 2017-07-01    1.303527
# 2017-08-01    1.019500
# 2017-09-01    0.972045
# 2017-10-01    0.768140
# 2017-11-01    0.715989
# 2017-12-01    0.767216
# 2018-01-01    1.061060
# 2018-02-01    0.977188
# 2018-03-01    1.103527
# 2018-04-01    1.168776
# 2018-05-01    0.995048
# 2018-06-01    1.079715
# 2018-07-01    1.158704
# 2018-08-01    1.108922
# 2018-09-01    0.795607
# 2018-10-01    1.346219
# 2018-11-01    1.169427
# 2018-12-01    0.742273
# 2019-01-01    0.771371
# 2019-02-01    0.926847
# 2019-03-01    1.055286
# ...

# %%
res.trend[8]*res.seasonal[8]*res.resid[8]
# Out:
# 223.62

# %%
pd.DataFrame(res.observed/res.trend).plot()
# Out:
# <Axes: xlabel='Bill_Date'>

# %%
import datetime
import pandas as pd
import requests
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rcParams['figure.figsize']=(10, 8)
mpl.rcParams['axes.grid'] = False

# %%
coindeskURL = 'https://api.coindesk.com/v1/bpi/historical/close.json?'

# %%
coindeskURL
# Out:
# 'https://api.coindesk.com/v1/bpi/historical/close.json?'

# %%
start = datetime.date(2017, 1, 1)
end = datetime.date(2020, 7, 2)

# %%
url = f'{coindeskURL}start={start:%Y-%m-%d}&end={end:%Y-%m-%d}'

# %%
result = requests.get(url)
result.content
# Out:
# b'{"bpi":{"2017-01-01":964.325,"2017-01-02":1009.9738,"2017-01-03":1028.3338,"2017-01-04":1047.1,"2017-01-05":1140.385,"2017-01-06":985.9388,"2017-01-07":837.8363,"2017-01-08":923.5238,"2017-01-09":889.3388,"2017-01-10":905.2263,"2017-01-11":910.6063,"2017-01-12":772.6613,"2017-01-13":784.8938,"2017-01-14":820.6888,"2017-01-15":821.1963,"2017-01-16":830.74,"2017-01-17":848.5813,"2017-01-18":890.2938,"2017-01-19":888.0625,"2017-01-20":896.1638,"2017-01-21":920.5888,"2017-01-22":934.7775,"2017-01-23":920.365,"2017-01-24":912.2125,"2017-01-25":898.55,"2017-01-26":901.05,"2017-01-27":912.8438,"2017-01-28":919.795,"2017-01-29":920.8288,"2017-01-30":916.9113,"2017-01-31":921.3513,"2017-02-01":973.065,"2017-02-02":982.8275,"2017-02-03":1020.09,"2017-02-04":1011.215,"2017-02-05":1029.4012,"2017-02-06":1019.3125,"2017-02-07":1029.4088,"2017-02-08":1067.7088,"2017-02-09":1072.205,"2017-02-10":974.9588,"2017-02-11":997.2275,"2017-02-12":1004.7138,"2017-02-13":1004.8538,"2017-02-14":994.58,"2017
# ...

# %%
data = pd.read_json(result.content.decode("utf-8")).iloc[:-2, :1]
data.index.name = 'date'
data.index = pd.to_datetime(data.index)
data
# Out:
#                   bpi
# date
# 2017-01-01   964.3250
# 2017-01-02  1009.9738
# 2017-01-03  1028.3338
# 2017-01-04  1047.1000
# 2017-01-05  1140.3850
# ...               ...
# 2020-06-28  9101.8501
# 2020-06-29  9188.0614
# 2020-06-30  9148.4449
# 2020-07-01  9236.3168
# 2020-07-02  9097.7974
#
# [1279 rows x 1 columns]

# %%
data.plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.resample('Q').mean()
# Out:
#                      bpi
# date
# 2017-03-31   1032.854171
# 2017-06-30   1914.986338
# 2017-09-30   3481.034815
# 2017-12-31   9292.903147
# 2018-03-31  10473.551614
# 2018-06-30   7734.210633
# 2018-09-30   6782.595947
# 2018-12-31   5153.967428
# 2019-03-31   3745.025510
# 2019-06-30   7270.903732
# 2019-09-30  10369.828125
# 2019-12-31   7984.696154
# 2020-03-31   8281.618885
# 2020-06-30   8673.854059
# 2020-09-30   9167.057100

# %%
data.resample('Q').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.resample('Q').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data[:5]
# Out:
#                   bpi
# date
# 2017-01-01   964.3250
# 2017-01-02  1009.9738
# 2017-01-03  1028.3338
# 2017-01-04  1047.1000
# 2017-01-05  1140.3850

# %%
data[:5].diff()
# Out:
#                 bpi
# date
# 2017-01-01      NaN
# 2017-01-02  45.6488
# 2017-01-03  18.3600
# 2017-01-04  18.7662
# 2017-01-05  93.2850

# %%
data[:5].diff(2)
# Out:
#                  bpi
# date
# 2017-01-01       NaN
# 2017-01-02       NaN
# 2017-01-03   64.0088
# 2017-01-04   37.1262
# 2017-01-05  112.0512

# %%
pd.concat([data['bpi'], data['bpi'].diff(2), data['bpi'].diff()], axis=1).plot()
# Out:
# <Axes: xlabel='date'>

# %%
data[:5].shift()
# Out:
#                   bpi
# date
# 2017-01-01        NaN
# 2017-01-02   964.3250
# 2017-01-03  1009.9738
# 2017-01-04  1028.3338
# 2017-01-05  1047.1000

# %%
data[:5].shift(2)
# Out:
#                   bpi
# date
# 2017-01-01        NaN
# 2017-01-02        NaN
# 2017-01-03   964.3250
# 2017-01-04  1009.9738
# 2017-01-05  1028.3338

# %%
data[:5].tshift()
# Out:
# <ipython-input-52-1eebd7bced17>:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   data[:5].tshift()
#                   bpi
# date
# 2017-01-02   964.3250
# 2017-01-03  1009.9738
# 2017-01-04  1028.3338
# 2017-01-05  1047.1000
# 2017-01-06  1140.3850

# %%
data[:5].tshift(2)
# Out:
# <ipython-input-53-da555377c95d>:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   data[:5].tshift(2)
#                   bpi
# date
# 2017-01-03   964.3250
# 2017-01-04  1009.9738
# 2017-01-05  1028.3338
# 2017-01-06  1047.1000
# 2017-01-07  1140.3850

# %%
data[:5] - data[:5].shift()
# Out:
#                 bpi
# date
# 2017-01-01      NaN
# 2017-01-02  45.6488
# 2017-01-03  18.3600
# 2017-01-04  18.7662
# 2017-01-05  93.2850

# %%
data[:5] - data[:5].shift(2)
# Out:
#                  bpi
# date
# 2017-01-01       NaN
# 2017-01-02       NaN
# 2017-01-03   64.0088
# 2017-01-04   37.1262
# 2017-01-05  112.0512

# %%
pd.concat([data, data-data.shift(), data.tshift(365)], axis = 1).plot()
# Out:
# <ipython-input-56-3576f7c1e5d2>:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   pd.concat([data, data-data.shift(), data.tshift(365)], axis = 1).plot()
# <Axes: xlabel='date'>

# %%
data.rolling(window=10).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.rolling(window=10).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.resample('W').mean().rolling(window=10).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.rolling(window=50).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.resample('W').mean().rolling(window=10).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.resample('W').mean().rolling(window=10).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.rolling(window=50).mean().plot()
data.rolling(window=50, win_type = 'gaussian').sum(std=10).plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.ewm(span=50).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
pd.concat([data, data.rolling(window=100).mean(), data.ewm(span=100).mean()], axis=1).plot()
# Out:
# <Axes: xlabel='date'>

# %%
data.groupby(data.index.dayofweek).mean()
# Out:
#               bpi
# date
# 0     6607.179104
# 1     6597.713860
# 2     6607.120999
# 3     6584.269647
# 4     6585.509408
# 5     6616.659732
# 6     6569.988007

# %%
data.groupby(data.index.month).mean()
# Out:
#               bpi
# date
# 1     6458.369020
# 2     5962.707796
# 3     5255.099965
# 4     5389.345622
# 5     6720.804677
# 6     7074.571907
# 7     6817.976326
# 8     7066.348489
# 9     6797.046348
# 10    6711.515451
# 11    7133.771634
# 12    8575.201668

# %%
data.groupby(data.index.year).mean()
# Out:
#               bpi
# date
# 2017  3951.843629
# 2018  7519.442859
# 2019  7362.522655
# 2020  8485.229087

# %%
data[:5].cumsum()
# Out:
#                   bpi
# date
# 2017-01-01   964.3250
# 2017-01-02  1974.2988
# 2017-01-03  3002.6326
# 2017-01-04  4049.7326
# 2017-01-05  5190.1176

# %%
data[:5].pct_change(2)
# Out:
#                  bpi
# date
# 2017-01-01       NaN
# 2017-01-02       NaN
# 2017-01-03  0.066377
# 2017-01-04  0.036760
# 2017-01-05  0.108964

# %%
data[:5].expanding().mean()
# Out:
#                     bpi
# date
# 2017-01-01   964.325000
# 2017-01-02   987.149400
# 2017-01-03  1000.877533
# 2017-01-04  1012.433150
# 2017-01-05  1038.023520

# %%
data[:5].expanding().sum()
# Out:
#                   bpi
# date
# 2017-01-01   964.3250
# 2017-01-02  1974.2988
# 2017-01-03  3002.6326
# 2017-01-04  4049.7326
# 2017-01-05  5190.1176
